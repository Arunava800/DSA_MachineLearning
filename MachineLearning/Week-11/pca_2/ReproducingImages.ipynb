# %%
from sklearn import decomposition, datasets
import numpy as np
import matplotlib.pyplot as plt

# %%
olive = datasets.fetch_olivetti_faces()
olive.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'DESCR'])

# %%
x = olive.data
y = olive.target

# %%
pca = decomposition.PCA()
transformed_data = pca.fit_transform(x)
transformed_data.shape
# Out:
# (400, 400)

# %%
k = 0
total = sum(pca.explained_variance_)
currSum = 0
while currSum/total < 0.99:
    currSum += pca.explained_variance_[k]
    k += 1

# %%
pca = decomposition.PCA(n_components = k, whiten=True)
transform_data = pca.fit_transform(x)

# %%
pca.explained_variance_.shape
# Out:
# (260,)

# %%
x_approx = pca.inverse_transform(transform_data)
x_approx.shape
# Out:
# (400, 4096)

# %%
x_approx_image = x_approx.reshape((400,64,64))
x_approx_image.shape
# Out:
# (400, 64, 64)

# %%
fig = plt.figure(figsize=(8,8))
for i in range(64):
    ax = fig.add_subplot(8,8, i+1)
    ax.imshow(x_approx_image[i], cmap = plt.cm.bone)
plt.show()

# %%
eigen_vectors = pca1.components_
eigen_vectors.shape
# Out:
# (260, 4096)

# %%
eigenfaces = eigen_vectors.reshape((260,64,64))

# %%
fig = plt.figure(figsize=(8,8))
for i in range(64):
    ax = fig.add_subplot(8,8, i+1)
    ax.imshow(eigenfaces[i])
plt.show()
