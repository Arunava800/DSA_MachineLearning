# %%
from sklearn import datasets
from sklearn.decomposition import PCA
import numpy as np
from matplotlib import pyplot as plt

# %%
olive = datasets.fetch_olivetti_faces()
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\aruna\scikit_learn_data

# %%
olive.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'DESCR'])

# %%
olive.data.shape
# Out:
# (400, 4096)

# %%
olive.images.shape
# Out:
# (400, 64, 64)

# %%
fig = plt.figure(figsize=(8,8))
for  i in range(64):
    ax = fig.add_subplot(8,8,i+1)
    ax.imshow(olive.images[i], cmap = plt.cm.bone)
plt.show()

# %%
x = olive.data
y = olive.target
pca = PCA()
pca.fit_transform(x)
pca.components_.shape
# Out:
# (400, 4096)

# %%
currSum = 0
k = 0
total = sum(pca.explained_variance_)
while currSum/ total < 0.99:
    currSum += pca.explained_variance_[k]
    k += 1
print(k)
# Out:
# 260

# %%
precise_pca = PCA(n_components = k)
transformed_data = pca.fit_transform(x)
transformed_data.shape
# Out:
# (400, 400)
