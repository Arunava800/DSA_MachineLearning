# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv('training_x_y.csv')

# %%
test_data = pd.read_csv('test_diabetes_x_test.csv')

# %%
train_data
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0   -0.049105 -0.044642  0.160855 -0.046985 -0.029088 -0.019790 -0.047082
# 1   -0.070900  0.050680 -0.089197 -0.074528 -0.042848 -0.025739 -0.032356
# 2    0.001751 -0.044642 -0.070875 -0.022885 -0.001569 -0.001001  0.026550
# 3    0.048974  0.050680  0.081097  0.021872  0.043837  0.064134 -0.054446
# 4    0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# ..        ...       ...       ...       ...       ...       ...       ...
# 326  0.012648 -0.044642 -0.020218 -0.015999  0.012191  0.021233 -0.076536
# 327  0.019913 -0.044642 -0.057941 -0.057314 -0.001569 -0.012587  0.074412
# 328  0.023546 -0.044642  0.070319  0.025315 -0.034592 -0.014466 -0.032356
# 329  0.016281  0.050680  0.072474  0.076958 -0.008449  0.005575 -0.006584
# 330 -0.009147  0.050680 -0.030996 -0.026328 -0.011201 -0.001001 -0.021311
#
#            s4        s5        s6    Y
# 0    0.034309  0.028017  0.011349  346
# ...

# %%
test_data
# Out:
#      0.02354575262934580082  0.05068011873981870252  -0.03746250427835440266  \
# 0                 -0.078165               -0.044642                -0.073030
# 1                 -0.030942                0.050680                 0.001339
# 2                 -0.005515                0.050680                 0.001339
# 3                 -0.020045               -0.044642                -0.084886
# 4                 -0.034575               -0.044642                -0.037463
# ..                      ...                     ...                      ...
# 105                0.009016                0.050680                 0.069241
# 106                0.005383               -0.044642                 0.049840
# 107                0.009016               -0.044642                -0.012673
# 108                0.019913               -0.044642                -0.034229
# 109                0.016281                0.050680                 0.009961
#
# ...

# %%
test_data.columns =['age','sex','bmi','bp','s1','s2','s3', 's4','s5','s6']

# %%
test_data.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0 -0.078165 -0.044642 -0.073030 -0.057314 -0.084126 -0.074277 -0.024993
# 1 -0.030942  0.050680  0.001339 -0.005671  0.064477  0.049416 -0.047082
# 2 -0.005515  0.050680  0.001339 -0.084857 -0.011201 -0.016658  0.048640
# 3 -0.020045 -0.044642 -0.084886 -0.026328 -0.035968 -0.034194  0.041277
# 4 -0.034575 -0.044642 -0.037463 -0.060757  0.020446  0.043466 -0.013948
#
#          s4        s5        s6
# 0 -0.039493 -0.018118 -0.083920
# 1  0.108111  0.083797  0.003064
# 2 -0.039493 -0.041180 -0.088062
# 3 -0.051671 -0.082381 -0.046641
# 4 -0.002592 -0.030751 -0.071494

# %%
train_data.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0 -0.049105 -0.044642  0.160855 -0.046985 -0.029088 -0.019790 -0.047082
# 1 -0.070900  0.050680 -0.089197 -0.074528 -0.042848 -0.025739 -0.032356
# 2  0.001751 -0.044642 -0.070875 -0.022885 -0.001569 -0.001001  0.026550
# 3  0.048974  0.050680  0.081097  0.021872  0.043837  0.064134 -0.054446
# 4  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
#
#          s4        s5        s6    Y
# 0  0.034309  0.028017  0.011349  346
# 1 -0.002592 -0.012908 -0.054925  104
# 2 -0.039493 -0.022512  0.007207   49
# 3  0.071210  0.032433  0.048628  180
# 4 -0.002592 -0.014956  0.011349  110

# %%
train_data.describe()
# Out:
#               age         sex         bmi          bp          s1          s2  \
# count  331.000000  331.000000  331.000000  331.000000  331.000000  331.000000
# mean    -0.000214   -0.000293    0.000053   -0.001045   -0.001423   -0.001220
# std      0.047207    0.047618    0.048627    0.047621    0.047371    0.046936
# min     -0.107226   -0.044642   -0.090275   -0.102071   -0.126781   -0.115613
# 25%     -0.034575   -0.044642   -0.035307   -0.036656   -0.035968   -0.029967
# 50%      0.005383   -0.044642   -0.008362   -0.005671   -0.004321   -0.004445
# 75%      0.038076    0.050680    0.030979    0.032775    0.027326    0.028905
# max      0.110727    0.050680    0.170555    0.132044    0.153914    0.198788
#
#                s3          s4          s5          s6           Y
# count  331.000000  331.000000  331.000000  331.000000  331.000000
# mean     0.000440   -0.001473   -0.001594    0.000099  149.722054
# std      0.047303    0.046591    0.048088    0.047263   76.796907
# ...

# %%
train_data.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# Y      0
# dtype: int64

# %%
test_data.describe()
# Out:
#               age         sex         bmi          bp          s1          s2  \
# count  110.000000  110.000000  110.000000  110.000000  110.000000  110.000000
# mean     0.000430    0.000420    0.000183    0.003573    0.005111    0.004357
# std      0.049214    0.047808    0.044751    0.047667    0.047665    0.049281
# min     -0.103593   -0.044642   -0.084886   -0.112400   -0.096510   -0.094632
# 25%     -0.040932   -0.044642   -0.031804   -0.032353   -0.030464   -0.030124
# 50%      0.009016   -0.044642   -0.005128   -0.000506    0.001871   -0.000531
# 75%      0.034443    0.050680    0.031517    0.047694    0.031454    0.035481
# max      0.096197    0.050680    0.128521    0.097616    0.133274    0.131461
#
#                s3          s4          s5          s6
# count  110.000000  110.000000  110.000000  110.000000
# mean    -0.001029    0.004791    0.005075   -0.000174
# std      0.048875    0.050581    0.046163    0.049088
# ...

# %%
test_data.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
x = train_data.drop('Y', axis = 1)

# %%
y = train_data.Y

# %%
x.shape, test_data.shape
# Out:
# ((331, 10), (110, 10))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train , y_test = train_test_split(x,y, test_size = 0.33, random_state = 42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((221, 10), (110, 10), (221,), (110,))

# %%
from sklearn.linear_model import LinearRegression
alg = LinearRegression()
alg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
train_score = alg.score(x_train, y_train)
test_score = alg.score(x_test, y_test)
print(f"Training Score {train_score:.5f}")
print(f"Test Score {test_score:.5f}")
# Out:
# Training Score 0.52851
# Test Score 0.39162

# %%
slope = alg.coef_
intercpet = alg.intercept_
print(f"The coefficient is {slope.mean():.5f}")
print(f"The intercept is {intercept:.5f}")
# Out:
# The coefficient is 108.98636
# The intercept is 151.05263

# %%
y_preds = alg.predict(test_data)
predicted_score = alg.score(test_data, y_preds)
print(f"The predicted score is {predicted_score*100:.5f}")
# Out:
# The predicted score is 100.00000

# %%
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=(10,10),sharey=True)
plt.subplots_adjust(hspace=0.35)
fig.add_gridspec()
rows, cols, index = 0,0,0
while True:
    if cols > 1:
        cols = 0
        rows += 1
    if rows > 4 :
        break
    ax[rows][cols].scatter(x_train[column_names[index]], y_train)
    line = slope[index] * x_train[column_names[index]] + intercept 
    ax[rows][cols].plot(x_train[column_names[index]], line)
    ax[rows][cols].set(xlabel = column_names[index])
    index += 1
    cols += 1
fig.suptitle("X_train Features Vs. Y_train Values")
plt.show()

# %%
fig, ax = plt.subplots(nrows = 5, ncols= 2, figsize=(10,10))
plt.subplots_adjust(hspace = 0.35)
rows, cols, index = 0, 0, 0
while True:
    if cols > 1:
        cols = 0
        rows += 1
    if rows > 4:
        break
    ax[rows][cols].scatter(x_test[column_names[index]], y_test)
    line = slope[index]*x_test[column_names[index]] + intercept
    ax[rows][cols].plot(x_test[column_names[index]], line)
    ax[rows][cols].set(xlabel = column_names[index])
    cols += 1
    index += 1

fig.suptitle("X_test Vs. Y_test")
plt.show()

# %%
fig, ax = plt.subplots(nrows = 5, ncols= 2, figsize=(10,10))
plt.subplots_adjust(hspace = 0.35)
rows, cols, index = 0, 0, 0
while True:
    if cols > 1:
        cols = 0
        rows += 1
    if rows > 4:
        break
    ax[rows][cols].scatter(test_data[column_names[index]], y_preds)
    line = slope[index]*test_data[column_names[index]] + intercept
    ax[rows][cols].plot(test_data[column_names[index]], line)
    ax[rows][cols].set(xlabel = column_names[index])
    cols += 1
    index += 1

fig.suptitle("Test_data Vs. Y_Preds")
plt.show()

# %%
test_data["Y"] = y_preds

# %%
test_data.to_csv('Predictions.csv')
